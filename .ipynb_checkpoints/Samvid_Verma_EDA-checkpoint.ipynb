# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

customers = pd.read_csv("Customers.csv")
products = pd.read_csv("Products.csv")
transactions = pd.read_csv("Transactions.csv")

merged = transactions.merge(customers, on="CustomerID").merge(products, on="ProductID")

merged['TransactionDate'] = pd.to_datetime(merged['TransactionDate'], errors='coerce')
customers['SignupDate'] = pd.to_datetime(customers['SignupDate'], errors='coerce')

plt.figure(figsize=(8, 5))
sns.countplot(data=customers, x='Region', palette='viridis', order=customers['Region'].value_counts().index)
plt.title('Regional Distribution of Customers')
plt.ylabel('Number of Customers')
plt.xlabel('Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("regional_distribution.png")
plt.show()

top_categories = merged.groupby('Category')['TotalValue'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
top_categories.plot(kind='bar', color='skyblue')
plt.title('Top Product Categories by Total Sales')
plt.ylabel('Revenue (USD)')
plt.xlabel('Product Category')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("top_categories.png")
plt.show()

merged['Month'] = merged['TransactionDate'].dt.to_period('M')
monthly_sales = merged.groupby('Month')['TotalValue'].sum()
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='line', marker='o', color='green')
plt.title('Monthly Sales Trends')
plt.ylabel('Revenue (USD)')
plt.xlabel('Month')
plt.grid(True)
plt.tight_layout()
plt.savefig("monthly_sales_trends.png")
plt.show()

top_customers = merged.groupby('CustomerName')['TotalValue'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
top_customers.plot(kind='bar', color='orange')
plt.title('Top 10 Customers by Spending')
plt.ylabel('Total Spending (USD)')
plt.xlabel('Customer Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("top_customers.png")
plt.show()

most_popular_products = merged.groupby('ProductName')['Quantity'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
most_popular_products.plot(kind='bar', color='purple')
plt.title('Top 10 Most Popular Products by Quantity Sold')
plt.ylabel('Quantity Sold')
plt.xlabel('Product Name')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("most_popular_products.png")
plt.show()

print("\nKey Insights:")
print("1. South America has the highest number of customers.")
print(f"2. The highest revenue-generating product category is '{top_categories.idxmax()}' with total sales of ${top_categories.max():,.2f}.")
print(f"3. The top customer is '{top_customers.idxmax()}' with total spending of ${top_customers.max():,.2f}.")
print(f"4. Monthly sales trends indicate the highest revenue in {monthly_sales.idxmax()} with ${monthly_sales.max():,.2f}.")
print(f"5. The most popular product is '{most_popular_products.idxmax()}' with {most_popular_products.max()} units sold.")

regional_distribution = customers['Region'].value_counts()
regional_distribution.to_csv("regional_distribution.csv")
top_categories.to_csv("top_categories.csv")
top_customers.to_csv("top_customers.csv")
most_popular_products.to_csv("most_popular_products.csv")
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_22644\3125149319.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=customers, x='Region', palette='viridis', order=customers['Region'].value_counts().index)
# Key Insights:
# 1. South America has the highest number of customers.
# 2. The highest revenue-generating product category is 'Books' with total sales of $192,147.47.
# 3. The top customer is 'Paul Parsons' with total spending of $10,673.87.
# 4. Monthly sales trends indicate the highest revenue in 2024-07 with $71,366.39.
# 5. The most popular product is 'ActiveWear Smartwatch' with 100 units sold.
